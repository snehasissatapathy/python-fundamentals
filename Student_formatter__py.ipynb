# %%
# Student Information Formatter

name = input("Enter student name: ")
branch = input("Enter branch: ")
cgpa = float(input("Enter CGPA: "))

print("\n--- Student Report ---")

print(f"Name   : {name}")
print(f"Branch : {branch}")
print(f"CGPA   : {cgpa}")
# Out:
# Enter student name: Snehasis
# Enter branch: ECE
# Enter CGPA: 6.95
#
# --- Student Report ---
# Name   : Snehasis
# Branch : ECE
# CGPA   : 6.95
