# %%
# python fundamental assignments
## 1.why is python is developer friendly?
python is developer friendly because:
1. simple and readable syntax
2. large library support
3. faster development process
-----
## 2. Difference between variable , object and memory reference?

-variable: Name used to store data
-object: actual data or value
-memory reference: location of object in memory
-----
## 3.variable are labels not boxes

variables point to objects in memory instead of storing values directly.
example:
a = 10
b = a

Both point to same object.
-----
## 4. what is a dynamic typing?

In python datatype is decided during runtime.

Example:
x = 10
x = "Hello"
Python allows data type changing automatically.
